# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\logiciels\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: pyyaml in c:\logiciels\anaconda3\lib\site-packages (from keras) (5.1.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\logiciels\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\logiciels\anaconda3\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\logiciels\anaconda3\lib\site-packages (from keras) (1.16.5)
# Requirement already satisfied: scipy>=0.14 in c:\logiciels\anaconda3\lib\site-packages (from keras) (1.3.1)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\logiciels\anaconda3\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied: h5py in c:\logiciels\anaconda3\lib\site-packages (from keras) (2.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow-gpu==2.0.0
# Out:
# Requirement already satisfied: tensorflow-gpu==2.0.0 in c:\logiciels\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: gast==0.2.2 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.16.5)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (2.0.1)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.0.8)
# Requirement already satisfied: grpcio>=1.8.6 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.26.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (0.1.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (1.12.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (0.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (0.33.6)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (2.0.2)
# Requirement already satisfied: protobuf>=3.6.1 in c:\logiciels\anaconda3\lib\site-packages (from tensorflow-gpu==2.0.0) (3.11.2)
# Requirement already satisfied: h5py in c:\logiciels\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.0.0) (2.9.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\logiciels\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\logiciels\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.10.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\logiciels\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\logiciels\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\logiciels\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (41.2.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\logiciels\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\logiciels\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\logiciels\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\logiciels\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\logiciels\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\logiciels\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.2.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\logiciels\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (4.0.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\logiciels\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\logiciels\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\logiciels\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.0) (0.4.7)

# %%
import tensorflow as tf
import requests
import shutil
from keras.preprocessing.image import load_img
from matplotlib import pyplot as plt
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('Data/landscapeSet_v3.csv')

# %%
#get image from url 
def load_image_set(dataframe):
    for i in range(0,len(dataframe)) :
        image_url =dataframe.iloc[i,2]
        # Open the url image, set stream to True, this will return the stream content.
        resp = requests.get(image_url, stream=True)
        # Open a local file with wb ( write binary ) permission.
        local_file = open('images_2000/_img_'+str(i)+'.jpg', 'wb')
        
        # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
        resp.raw.decode_content = True
        # Copy the response stream raw data to local image file.
        shutil.copyfileobj(resp.raw, local_file)
        # Remove the image url response object.
        del resp

# %%
load_image_set(df)

# %%
#load an and display
img = load_img('images/local_image.jpg')
fig = plt.figure(1, figsize=(10, 10))
plt.imshow(img)

# %%
string = 'ee'
if string :
    print('not empty')
# Out:
# not empty
